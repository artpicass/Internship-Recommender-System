# %% [markdown]
# **WEEK 2 - ITEM BASED COLABORATIVE FILTERING (IBCF)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from scipy.sparse import csr_matrix
import time
import os
from os import path

# %%
# !pip install surprise
# Out:
# Collecting surprise
#   Downloading https://files.pythonhosted.org/packages/61/de/e5cba8682201fcf9c3719a6fdda95693468ed061945493dea2dd37c5618b/surprise-0.1-py2.py3-none-any.whl
# Collecting scikit-surprise
#   Downloading https://files.pythonhosted.org/packages/f5/da/b5700d96495fb4f092be497f02492768a3d96a3f4fa2ae7dea46d4081cfa/scikit-surprise-1.1.0.tar.gz (6.4MB)
#      |████████████████████████████████| 6.5MB 2.8MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise->surprise) (0.15.1)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise->surprise) (1.18.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise->surprise) (1.4.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise->surprise) (1.12.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.0-cp36-cp36m-linux_x86_64.whl size=1675724 sha256=62923ee97adc840016aa1601ee84bafd1c1c51d18c672d254c6cc29d92d515c7
#   Stored in directory: /root/.cache/pip/wheels/cc/fa/8c/16c93fccce688ae1bde7d979ff102f7bee980d9cfeb8641bcf
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.0 surprise-0.1

# %%
from surprise import Reader, Dataset ,KNNWithMeans

# %%
rating = pd.read_csv('ratings.csv',sep=',', names=['UserID','MovieID','Rating','Timestamp'])
rating = rating.drop(columns='Timestamp')

# %%
reader = Reader(rating_scale=(1,5))     #Rating scale is used for every rating i.e 1 to 5

# %%
#Loads from Dataframe into data
data = Dataset.load_from_df(rating[['UserID','MovieID','Rating']],reader)

# %%
#Compute similarity between items
methods = {
    'name':'cosine',
    'user_based': False
}
knn  = KNNWithMeans(sim_options=methods)

# %%
#Spliting the data into training
trainingdata = data.build_full_trainset()
#Fit KNNwithmean
knn.fit(trainingdata)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
from surprise.model_selection import GridSearchCV

# %%
def prediction(userid,movieid):
  pred = knn.predict(userid,movieid)
  rating =  pred.est
  print('User {} rate {:.1f}/5 of movieid {}'.format(userid,rating,movieid))

# %%
#User having userid 35 will give 3.74 ratings to movie having id 6
prediction(35,45)
# Out:
# User 35 rate 3.3/5 of movieid 45

# %%
#Cheaking accuracy on dataset  - 'data'
'''def rmse(cv):
  sim_options = {
      "name": ["msd", "cosine"],
      "min_support": [3],
      "user_based": [False],
  }
  param_grid = {'sim_options': sim_options}
  gs = GridSearchCV(KNNWithMeans, param_grid , measures=['rmse'] ,cv = cv)
  gs.fit(data)
  print(gs.best_score)
  print(gs.best_params)'''

# %%
rmse(3)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# {'rmse': nan}
# {'rmse': {'sim_options': {'name': 'msd', 'min_support': 3, 'user_based': False}}}
